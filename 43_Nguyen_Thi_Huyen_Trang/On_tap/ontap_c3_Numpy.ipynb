# %% [markdown]
# ##### Câu 1:
# ##### NumPy (Numerical Python) là thư viện hỗ trợ xử lý mảng nhiều chiều và tính toán số học hiệu năng cao trong Python.
#
# ##### Được dùng phổ biến vì:
# * Tốc độ nhanh
# * Hỗ trợ mảng nhiều chiều
# * Cú pháp gọn, dễ vector hóa
# * Nền tảng cho Pandas

# %% [markdown]
# ##### Câu 2:
# * Cung cấp ndarray – cấu trúc mảng chuẩn
# * Tối ưu bộ nhớ & tốc độ
# * Các thư viện dữ liệu khác đều xây dựng trên NumPy

# %% [markdown]
# ##### Câu 3:
# | NumPy array       | Python list        |
# | ----------------- | ------------------ |
# | Cùng kiểu dữ liệu | Nhiều kiểu         |
# | Nhanh, tối ưu     | Chậm               |
# | Hỗ trợ vector hóa | Phải dùng vòng lặp |
# | Tốn ít bộ nhớ     | Tốn hơn            |

# %% [markdown]
# ##### Câu 4:
# ndarray là mảng n chiều trong NumPy, chứa các phần tử cùng kiểu dữ liệu, lưu liên tiếp trong bộ nhớ

# %% [markdown]
# ##### Câu 5:

# %%
import numpy as np

np.array([1, 2, 3])                 # 1D
np.array([[1, 2], [3, 4]])          # 2D
np.array([[[1], [2]], [[3], [4]]])  # 3D
# Out:
# array([[[1],
#         [2]],
#
#        [[3],
#         [4]]])

# %% [markdown]
# ##### Câu 6:

# %%
arr.ndim     # số chiều
arr.shape    # kích thước

# %% [markdown]
# ##### Câu 7:

# %%
arr.dtype

# %% [markdown]
# ##### Câu 8:
# ##### Các cách truy cập dữ liệu:
#
# * Indexing: arr[0, 1]
# * Slicing: arr[:, 1]
# * Boolean indexing
# * Fancy indexing

# %% [markdown]
# ##### Câu 9: Khác nhau giữa mảng[:, 0] và mảng[:, [0]]
#
# * mảng[:, 0] → mảng 1D
# * mảng[:, [0]] → mảng 2D

# %% [markdown]
# ##### Câu 10:
# Fancy indexing trong NumPy là kỹ thuật truy cập các phần tử của mảng bằng một tập hợp chỉ số (danh sách hoặc mảng chỉ số) thay vì sử dụng chỉ số đơn hoặc lát cắt liên tục.

# %% [markdown]
# ##### Câu 11:

# %%
arr.reshape(2, 3)

# %% [markdown]
# ##### Câu 12:

# %%
#Chia
np.split(arr, 2)

#Nối
np.concatenate([a, b])
np.vstack([a, b])
np.hstack([a, b])
