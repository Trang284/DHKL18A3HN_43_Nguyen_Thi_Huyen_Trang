# %% [markdown]
# Câu 1: Hãy so sánh lập trình hướng đối tượng với lập trình cấu trúc?

# %% [markdown]
# *Lập trình hướng đối tượng (OOP):
# - Trọng tâm chính là bảo mật dữ liệu vì chỉ các đối tượng của một lớp mới được phép truy cập các thuộc tính hoặc chức năng của một lớp.
# - Có ba chế độ truy cập: "public", "private", "protected" được sử dụng như một phương thức truy cập để truy cập các thuộc tính hoặc chức năng.
# - Hỗ trợ kế thừa ho phép một lớp (class) có thể kế thừa các thuộc tính và phương thức từ các lớp khác đã được định nghĩa.
# - Tính năng ẩn dữ liệu và bộ chỉ định truy cập giới hạn quyền truy cập vào các thuộc tính hoặc chức năng làm tăng tính bảo mật.
# - Giúp quản lý dữ liệu tốt hơn, giảm trùng lặp mã, tăng khả năng tái sử dụng.
#
# *Lập trình cấu trúc (POP):
# - Trọng tâm chính là về cách thức thực hiện nhiệm vụ của hệ thống, tuân theo biểu đồ dòng chảy để hoàn thành nhiệm vụ.
# - Không có chế độ truy cập cụ thể để truy cập các thuộc tính hoặc chức năng trong chương trình.
# - Không có khái niệm kế thừa.
# - Không có cách ẩn dữ liệu như OOP nên kém an toàn hơn.
# - Dễ gặp khó khăn khi mở rộng hoặc bảo trì chương trình lớn.

# %% [markdown]
# Câu 2: Tính chất đặc thù của lập trình hướng đối tượng?

# %% [markdown]
# * Các tính chất đặc thù của lập trình hướng đối tượng gồm:
#
#     1. Tính kế thừa (Inheritance):
#         - Cho phép một lớp (class) có thể kế thừa các thuộc tính và phương thức từ các lớp khác
#         đã được định nghĩa.
#     2. Tính đóng gói (Encapsulation):
#         -  Là quy tắc yêu cầu trạng thái bên trong của một đối tượng được bảo vệ và tránh truy cập được từ code bên ngoài (tức là code bên ngoài không thể trực tiếp nhìn thấy và thay đổi trạng thái của đối tượng đó).
#     3. Tính đa hình (Polymorphism):
#         - Là khái niệm mà hai hoặc nhiều lớp có những phương thức giống nhau nhưng có thể thực thi theo những cách thức khác nhau.
#     4. Tính trừu tượng (Abstract):
#         - Che giấu các chi tiết không cần thiết khỏi người sử dụng kiểu (type consumers*).
